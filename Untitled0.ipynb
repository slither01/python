# %% [markdown]
# <a href="https://colab.research.google.com/github/slither01/python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New section

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

try:
    import pydot
except ImportError:
    # !pip install pydot

try:
    import libarchive
except ImportError:
    # !apt-get -qq install -y libarchive-dev

# Additional installations
# !apt-get -qq install -y libfluidsynth1
# !pip install matplotlib-venn
# Out:
# Selecting previously unselected package libarchive-dev:amd64.
# (Reading database ... 120880 files and directories currently installed.)
# Preparing to unpack .../libarchive-dev_3.6.0-1ubuntu1_amd64.deb ...
# Unpacking libarchive-dev:amd64 (3.6.0-1ubuntu1) ...
# Setting up libarchive-dev:amd64 (3.6.0-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# E: Package 'libfluidsynth1' has no installation candidate
# ...

# %%
coffee = pd.read_csv('cqi.csv')

# %%
coffee.head()
# Out:
#    Unnamed: 0  ID Country of Origin                 Farm Name  \
# 0           0   0          Colombia          Finca El Paraiso
# 1           1   1            Taiwan  Royal Bean Geisha Estate
# 2           2   2              Laos        OKLAO coffee farms
# 3           3   3        Costa Rica                 La Cumbre
# 4           4   4          Colombia           Finca Santuario
#
#                                 Lot Number                           Mill  \
# 0                               CQU2022015               Finca El Paraiso
# 1  The 2022 Pacific Rim Coffee Summit,T037       Royal Bean Geisha Estate
# 2  The 2022 Pacific Rim Coffee Summit,LA01  oklao coffee processing plant
# 3                               CQU2022017        La Montana Tarrazu MIll
# 4                               CQU2023002                Finca Santuario
#
#   ICO Number                   Company   Altitude                Region  ...  \
# ...

# %%
coffee.tail()
# Out:
#      Unnamed: 0   ID Country of Origin                             Farm Name  \
# 202         202  202            Brazil                     Fazenda Conquista
# 203         203  203         Nicaragua                      Finca San Felipe
# 204         204  204              Laos                                     -
# 205         205  205       El Salvador  Rosario de Maria II, Area de La Pila
# 206         206  206            Brazil                         Walter Matter
#
#            Lot Number                                       Mill  \
# 202            019/22                                   Dry Mill
# 203      017-053-0155                  Beneficio Atlantic Sébaco
# 204  105/3/VL7285-005                                   DRY MILL
# 205           0423A01  Optimum Coffee, San Salvador, El Salvador
# 206       1058 y 1059                      Beneficio humedo/seco
#
#            ICO Number                             Company  Altitude  \
# ...

# %%
coffee.shape
# Out:
# (207, 41)

# %%
coffee.isnull().sum()
# Out:
# Unnamed: 0               0
# ID                       0
# Country of Origin        0
# Farm Name                0
# Lot Number               0
# Mill                     0
# ICO Number               0
# Company                  0
# Altitude                 0
# Region                   0
# Producer                 0
# Number of Bags           0
# Bag Weight               0
# In-Country Partner       0
# Harvest Year             0
# Grading Date             0
# Owner                    0
# Variety                  0
# Status                   0
# Processing Method        0
# Aroma                    0
# Flavor                   0
# Aftertaste               0
# Acidity                  0
# Body                     0
# Balance                  0
# Uniformity               0
# Clean Cup                0
# Sweetness                0
# Overall                  0
# Defects                  0
# Total Cup Points         0
# Moisture Percentage      0
# Category One Defects     0
# ...

# %%
coffee.dropna(inplace = True)
#coffee.update(coffee.fullna(coffee.mean()))

# %%
plt.figure(2)
plt.subplot(121)
sns.distplot(coffee['ID'])
plt.subplot(122)
coffee['Category Two Defects'].plot.box(figsize=(5,5))
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,7))
sns.barplot(x = 'ID' , y = 'Category Two Defects', data=coffee)
# Out:
# <Axes: xlabel='ID', ylabel='Category Two Defects'>

# %%
sns.pairplot (coffee)

# %%
coffee.corr()
# Out:
#                       Unnamed: 0        ID  Number of Bags     Aroma  \
# Unnamed: 0              1.000000  1.000000        0.251725 -0.734897
# ID                      1.000000  1.000000        0.251725 -0.734897
# Number of Bags          0.251725  0.251725        1.000000 -0.232809
# Aroma                  -0.734897 -0.734897       -0.232809  1.000000
# Flavor                 -0.910767 -0.910767       -0.274177  0.678320
# Aftertaste             -0.896500 -0.896500       -0.253221  0.701070
# Acidity                -0.903772 -0.903772       -0.247951  0.689834
# Body                   -0.784526 -0.784526       -0.081739  0.572282
# Balance                -0.830985 -0.830985       -0.284369  0.574347
# Uniformity                   NaN       NaN             NaN       NaN
# Clean Cup                    NaN       NaN             NaN       NaN
# Sweetness                    NaN       NaN             NaN       NaN
# Overall                -0.889269 -0.889269       -0.298403  0.636740
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(coffee.corr(), cmap = 'coolwarm')
# Out:
# <Axes: >
